# %%
import pandas as pd
import json
import numpy as np
import re
import csv
from sklearn.feature_extraction.text import CountVectorizer

# %%
reviews = open('CellPhoneReview.json', 'r').read().strip().split('\n')
reviews = [json.loads(s) for s in reviews]
review_df = pd.DataFrame.from_dict(reviews)
review_df
# Out:
#               asin  overall  \
# 0       120401325X      5.0
# 1       120401325X      5.0
# 2       120401325X      4.0
# 3       120401325X      5.0
# 4       120401325X      3.0
# 5       120401325X      5.0
# 6       3998899561      1.0
# 7       3998899561      5.0
# 8       3998899561      5.0
# 9       3998899561      5.0
# 10      3998899561      5.0
# 11      3998899561      5.0
# 12      3998899561      5.0
# 13      3998899561      5.0
# 14      3998899561      5.0
# 15      3998899561      5.0
# 16      6073894996      5.0
# 17      6073894996      5.0
# 18      6073894996      1.0
# 19      6073894996      5.0
# 20      6073894996      5.0
# 21      6073894996      3.0
# 22      6073894996      4.0
# 23      6073894996      4.0
# 24      6073894996      5.0
# 25      6073894996      2.0
# 26      6073894996      4.0
# 27      6073894996      2.0
# 28      6073894996      4.0
# 29      6073894996      5.0
# ...            ...      ...
# 190889  B00LH1QXC0      5.0
# 190890  B00LH1QXC0      4.0
# 190891  B00LH1QZR8      5.0
# 190892  B00LH1QZR8      5.0
# 190893  B00LH1QZR8      5.0
# 190894  B00LH1QZR8      5.0
# 190895  B00LH1QZR8      5.0
# 190896  B00LH1R3C4      5.0
# 190897  B00LH1R3C4      5.0
# 190898  B00LH1R3C4      5.0
# 190899  B00LH1R3C4      5.0
# 190900  B00LH1R3C4      5.0
# 190901  B00LH1R5HW      5.0
# 190902  B00LH1R5HW      5.0
# 190903  B00LH1R5HW      5.0
# 190904  B00LH1R5HW      5.0
# 190905  B00LH1R5HW      5.0
# 190906  B00LH1R6SK      5.0
# 190907  B00LH1R6SK      5.0
# 190908  B00LH1R6SK      5.0
# 190909  B00LH1R6SK      5.0
# 190910  B00LH1R6SK      5.0
# 190911  B00LORXVUE      5.0
# 190912  B00LORXVUE      4.0
# 190913  B00LORXVUE      5.0
# 190914  B00LORXVUE      5.0
# 190915  B00LORXVUE      5.0
# 190916  B00LORXVUE      5.0
# 190917  B00LORXVUE      5.0
# 190918  B00LORXVUE      5.0
#
#                                                reviewText   reviewTime  \
# 0       These stickers work like the review says they ...  01 14, 2014
# 1       These are awesome and make my phone look so st...  06 26, 2014
# 2       Item arrived in great time and was in perfect ...  10 21, 2013
# 3       awesome! stays on, and looks great. can be use...   02 3, 2013
# 4       These make using the home button easy. My daug...  10 12, 2013
# 5       Came just as described.. It doesn't come unstu...  08 22, 2013
# 6       it worked for the first week then it only char...  11 21, 2013
# 7       Good case, solid build. Protects phone all aro...  09 25, 2013
# 8       This is a fantastic case. Very stylish and pro...   04 3, 2014
# 9       this case fits perfectly on the s4 and keeps m...  04 13, 2014
# 10      This is the first battery case I have had for ...  11 20, 2013
# 11      Performs exactly as advertised . It's very  st...   12 5, 2013
# 12      Unlike Most of the Rechargeable Battery cases,...  09 27, 2013
# 13      Just what I needed. I needed a phone case for ...  02 21, 2014
# 14      When there is no outlets, or chargers near by ...  04 18, 2014
# 15      It works great. Doesn't heat up like crazy lik...  08 25, 2013
# 16      Surprisingly, this inexpensive version works j...  05 11, 2013
# 17      I have tested this against the griffin dual ou...  09 19, 2012
# 18      It worked great for the first couple of weeks ...  05 29, 2013
# 19      I love that it has two ports for my phone and ...   06 6, 2014
# 20      just what you need, I am always having to char...  11 29, 2013
# 21      does not have the need amps to charge things l...  05 18, 2013
# 22      They are nothing special for sure, but it's ni...   06 8, 2014
# 23      I have several chargers. Have more than one ve...  01 11, 2014
# 24      I bought this a little skeptical. After I trie...  09 21, 2013
# 25      I am disappointed that the 1A didn't work with...  06 23, 2014
# 26      This is a nice charger but you can tell it was...  03 20, 2013
# 27                       After a week only one side works   07 3, 2014
# 28      Yo get exactly what you order in a timely fash...   02 7, 2013
# 29      This is a terribly awesome product in my Subar...  11 10, 2013
# ...                                                   ...          ...
# 190889  Perfect gift for a family member who loved sna...  07 21, 2014
# 190890  My boyfriend also has this case and he adores ...  07 21, 2014
# 190891  This is my favorite case in terms of feel. I'm...  07 18, 2014
# 190892  This is such a cool case.  I got it for myself...  07 21, 2014
# 190893               Punk retro texture!! Wonderful idea.  07 18, 2014
# 190894  Get your stud their own studded case with this...  07 21, 2014
# 190895  I got this case for the texture and I've been ...  07 21, 2014
# 190896  Great idea and it works well. I love the feel ...  07 18, 2014
# 190897  I love this galaxy-looking phone case! I paint...  07 19, 2014
# 190898  This case somewhat reminds me of space. I saw ...  07 17, 2014
# 190899  A leather case is truly a treat. It also is st...  07 18, 2014
# 190900  Got this case for my spouse to go with his bla...  07 18, 2014
# 190901  Another cool Valenz case. The pattern is why I...  07 18, 2014
# 190902  I am not obsessed with this case. I read some ...  07 19, 2014
# 190903  I've recently got a phone from my cousin in fa...  07 17, 2014
# 190904  I've gotten in a habit of rubbing it back and ...  07 18, 2014
# 190905  If you are looking for something unique, you h...  07 19, 2014
# 190906                        Great case design and feel.  07 18, 2014
# 190907  Feels fantastic. I feel like such a nerd buyin...  07 19, 2014
# 190908  I get so many compliments on this case. It was...  07 17, 2014
# 190909  Ahah, I love it. The case looks better than th...  07 18, 2014
# 190910  As someone who owns an iPhone, I absolutely lo...  07 18, 2014
# 190911  What a high quality cable. Right out of the pa...  07 22, 2014
# 190912  This one actually works unlike some others I b...  07 19, 2014
# 190913  I don't like the word "hate", so let's just sa...  07 18, 2014
# 190914  Works great just like my original one. I reall...  07 21, 2014
# 190915  Great product. Great packaging. High quality a...  07 21, 2014
# 190916  This is a great cable, just as good as the mor...  07 21, 2014
# 190917  I really like it becasue it works well with my...  07 20, 2014
# 190918  product as described, I have wasted a lot of m...  07 21, 2014
#
#             reviewerID                                            summary  \
# 0        ASY55RVNIL0UD                              Really great product.
# 1       A2TMXE2AFO7ONB                                     LOVE LOVE LOVE
# 2        AWJ0WZQYMYFQ4                                              Cute!
# 3        ATX7CZYFXI1KW          leopard home button sticker for iphone 4s
# 4        APX47D16JOP7H                                               Cute
# 5       A1JVVYYO7G56DS                                  best thing ever..
# 6        A6FGO4TBZ3QFZ                                    not a good Idea
# 7       A2JWEDW5FSVB0F                                         Solid Case
# 8        A8AJS1DW7L3JJ                                       Perfect Case
# 9       A2YO4SCWAWNYBI                                 Just what I needed
# 10      A3AFELPYTZH90T                                           A Winner
# 11       A6Q0P54QSP11J                        Absolutely love the case !!
# 12       ANMATY0L0HX6Y  Best Rechargeable Battery Case on the Market!!...
# 13      A1XBPVR8FE7TE1                              Exactly what I needed
# 14      A35C4777EXZZQH                                  5 star phone case
# 15       ACU3LCRX4A8RV                               SUPER DUPER QUALITY!
# 16      A1ZTTNS6SWFV52      Top Quality. Works like the Expensive Version
# 17      A38EHCCO532RYI                            High power as promised!
# 18      A2INSXDTE08WSJ                                           Horrible
# 19       A9NETBZNEW2TP                                           USB Port
# 20      A385HZRPXDDFCL                                        Works great
# 21       ALZQ9D8V53TI2                                           it works
# 22      A3VWU7S29LR2XX                     I like the fact they light up.
# 23      A3TOHPW7ES23NZ                                        Works great
# 24      A1LGWLFF0YD0KV                                        Works great
# 25      A2YODGM5RUZ7I1                    This doesn't work with my iPad.
# 26      A29OXVQRZ154KX                         Solid Charger but RF noisy
# 27      A2U5NF3IH4YVKH                                          Two Stars
# 28      A34XJA5OE33FP1                                                 Ok
# 29      A2DZO8MWVM4WKD         USB slots in a blue light that never quits
# ...                ...                                                ...
# 190889  A34KTJ4VWNBOHI                                 Makes a Great Gift
# 190890   A4XPE5UGK51IA                                         Ultra-cool
# 190891  A2G7RZI15ZPCTH                             Cool idea that worked!
# 190892  A2V247ZQT9OJIT                              Very cool phone case.
# 190893   AF30DHAVSYNZ0                                   cool, punky one!
# 190894  A34KTJ4VWNBOHI                                   Studs for a Stud
# 190895   A4XPE5UGK51IA                                 Very cool texture!
# 190896  A2G7RZI15ZPCTH                                               Feel
# 190897  A3BXNEABWRWJ1R                                        Bulletproof
# 190898  A1Q52UP42LZ6XY                                     One of a kind!
# 190899   AF30DHAVSYNZ0                            leather in any weather.
# 190900  A34KTJ4VWNBOHI                                     Looks Great On
# 190901  A2G7RZI15ZPCTH                                            Feel it
# 190902  A3BXNEABWRWJ1R                                           Obsessed
# 190903  A1Q52UP42LZ6XY                 Never seen a case like this before
# 190904   AF30DHAVSYNZ0                                      Well designed
# 190905  A34KTJ4VWNBOHI                         Grab Your Own Reptile Case
# 190906  A2G7RZI15ZPCTH                        Ssssssssuper Sssssatisfied.
# 190907  A3BXNEABWRWJ1R                                   Feel the python!
# 190908  A1Q52UP42LZ6XY                          You get what you pay for!
# 190909   AF30DHAVSYNZ0                                         Yesssssss!
# 190910  A34KTJ4VWNBOHI                        Beautiful Color and Texture
# 190911  A1Q1Z7IR79G52A  Must have, high quality charging cable for ipa...
# 190912  A388OX0ZF7OT8R                                          Long Wire
# 190913  A2BLFCOPSMBOZ9                                     Awesome cable!
# 190914  A1YMNTFLNDYQ1F                           This works just perfect!
# 190915  A15TX8B2L8B20S           Great replacement cable. Apple certified
# 190916  A3JI7QRZO1QG8X                                       Real quality
# 190917  A1NHB2VC68YQNM  I really like it becasue it works well with my...
# 190918  A1AG6U022WHXBF              I have wasted a lot of money on cords
#
#         unixReviewTime
# 0           1389657600
# 1           1403740800
# 2           1382313600
# 3           1359849600
# 4           1381536000
# 5           1377129600
# 6           1384992000
# 7           1380067200
# 8           1396483200
# 9           1397347200
# 10          1384905600
# 11          1386201600
# 12          1380240000
# 13          1392940800
# 14          1397779200
# 15          1377388800
# 16          1368230400
# 17          1348012800
# 18          1369785600
# 19          1402012800
# 20          1385683200
# 21          1368835200
# 22          1402185600
# 23          1389398400
# 24          1379721600
# 25          1403481600
# 26          1363737600
# 27          1404345600
# 28          1360195200
# 29          1384041600
# ...                ...
# 190889      1405900800
# 190890      1405900800
# 190891      1405641600
# 190892      1405900800
# 190893      1405641600
# 190894      1405900800
# 190895      1405900800
# 190896      1405641600
# 190897      1405728000
# 190898      1405555200
# 190899      1405641600
# 190900      1405641600
# 190901      1405641600
# 190902      1405728000
# 190903      1405555200
# 190904      1405641600
# 190905      1405728000
# 190906      1405641600
# 190907      1405728000
# 190908      1405555200
# 190909      1405641600
# 190910      1405641600
# 190911      1405987200
# 190912      1405728000
# 190913      1405641600
# 190914      1405900800
# 190915      1405900800
# 190916      1405900800
# 190917      1405814400
# 190918      1405900800
#
# [190919 rows x 7 columns]

# %%
# split dataset into poor reviews <3 and good reviews >3. reviews of rating 3 are ommitted as they are neutral
good_reviews = review_df [(review_df['overall']>3.0)]
poor_reviews = review_df [(review_df['overall']<3.0)]
good_reviewText = good_reviews['reviewText']
poor_reviewText = poor_reviews['reviewText']
good_summ = good_reviews['summary']
poor_summ = poor_reviews['summary']
poor_summ
# Out:
# 6                                           not a good Idea
# 18                                                 Horrible
# 25                          This doesn't work with my iPad.
# 27                                                Two Stars
# 31        don't waste your money, pay more and buy one a...
# 34                                       Works for a while.
# 39                                           not high power
# 43                            Works Fine, But It Died On ME
# 45                                               Be careful
# 62                                        Loved it at first
# 68                                  Don't waste your money!
# 69                                           bad experience
# 86                          Poor Quality Cell Phone Charger
# 100                                                    FAIL
# 102                                               Not good.
# 103                                      LIGHT DUTY FAILURE
# 105                                          Does not work.
# 115                     Stopped Working after 1 1/2 month..
# 119       It works...mostly as a conversation piece sinc...
# 125                                       Unfortunate item.
# 126        Cord did not last but a few days for some reason
# 128                                         Do not recomend
# 130                                          Not Very Good!
# 134                              It doesn't charge properly
# 137       wall adapter is not quick-chager Which the ad ...
# 142                    Not as nice as I thought it would be
# 143                                             Bad Quality
# 158                                                  Broken
# 169       Almost every positive review posted for this p...
# 173                                   Fake Positive Reviews
#                                 ...
# 189912                                             One Star
# 190003                         Not very comfortable.Updated
# 190008                                  Worked for a bit...
# 190009      I liked the fact that it was blue to see it ...
# 190011    These and others are the reason Apple created ...
# 190132                MOTOROLA'S LATEST DOG OF A CELL PHONE
# 190156       Not good at all.. Two dents on my tablet now:(
# 190165                       Quit working after a few uses!
# 190166                                 Some work some don't
# 190171                              Beware - Not for iPad 3
# 190179               Mixed results ...But not for the iPad!
# 190388           I don't like this phone.  Not easy to use.
# 190390                     Good phone with nice features, b
# 190454                                                  Rip
# 190460                             Broke after a few weeks!
# 190477          So Sad to Report that this item arrived DOA
# 190478                                             One Star
# 190526                      Not for a Samsung Galaxy Note 2
# 190654                                        Disappointing
# 190661                               Extremely Dissapointed
# 190750    Simply Put: **Belkin/ Micra Digital does a lot...
# 190751                                         Very Average
# 190752                         needs improvement. 2.5 stars
# 190755                   The people before me are sorcerers
# 190759                      Won't stick and semi-glare-free
# 190779                                       DONT Recommend
# 190782                         Not as good as it used to be
# 190784                                Didn't work for me...
# 190789                                          phone cover
# 190826                               Don't waste your money
# Name: summary, Length: 23967, dtype: object

# %%
# cleaning and preprocessing functions
replace_punctuation = re.compile("(\.)|(\;)|(\:)|(\!)|(\')|(\?)|(\,)|(\")|(\()|(\))|(\[)|(\])")

def clean_reviews(reviews):
    reviews = [replace_punctuation.sub("", line.lower()) for line in reviews]
    
    return reviews

# cleaning all datasets and saving as csv
good_reviewText = clean_reviews(good_reviewText)
with open('good_reviewText.csv', 'w') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL,delimiter='\n')
    wr.writerow(good_reviewText)
    
poor_reviewText = clean_reviews(poor_reviewText)
with open('poor_reviewText.csv', 'w') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL,delimiter='\n')
    wr.writerow(poor_reviewText)
    
good_summ = clean_reviews(good_summ)
with open('good_summ.csv', 'w') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL,delimiter='\n')
    wr.writerow(good_summ)
    
poor_summ = clean_reviews(poor_summ)
with open('poor_summ.csv', 'w') as myfile:
    wr = csv.writer(myfile, quoting=csv.QUOTE_ALL,delimiter='\n')
    wr.writerow(poor_summ)

# %% [markdown]
# ## Vectorizing

# %%
# reading in for vectorizing
gd_rt_df = pd.read_csv('good_reviewText.csv', header=None)
bd_rt_df = pd.read_csv('poor_reviewText.csv', header=None)
gd_summ_df = pd.read_csv('good_summ.csv', header=None)
bd_summ_df = pd.read_csv('poor_summ.csv', header=None)

# %%
# size of each list
print('size of gd_rt_df is',len(gd_rt_df.index))
print('size of bd_rt_df is',len(bd_rt_df.index))
print('size of gd_summ_df is',len(gd_summ_df.index))
print('size of bd_summ_df is',len(bd_summ_df.index))
# Out:
# size of gd_rt_df is 145877
# size of bd_rt_df is 23967
# size of gd_summ_df is 145877
# size of bd_summ_df is 23967

# %%
with open('good_summ.csv', 'r') as f:
    reader = csv.reader(f)
    good_summary = list(reader)

with open('poor_summ.csv', 'r') as f:
    reader = csv.reader(f)
    poor_summary = list(reader)
    
mid_good = int(len(good_summary)/2)
mid_poor = int(len(poor_summary)/2)
summaries_train_clean = good_summary[:mid_good] + poor_summary[:mid_poor]
summaries_test_clean = good_summary[mid_good+1:] + poor_summary[mid_poor+1:]

# %%
print('len of good summ[:mid_good]',len(good_summary[:mid_good]))
print('len of poor summ[:mid_poor]',len(poor_summary[:mid_poor]))
print('len of good summ[mid_good:]',len(good_summary[mid_good+1:]))
print('len of poor summ[mid_poor:]',len(poor_summary[mid_poor+1:]))

print('len of X',len(summaries_train_clean))
print('len of X_test',len(summaries_test_clean))
# Out:
# len of good summ[:mid_good] 72938
# len of poor summ[:mid_poor] 11983
# len of good summ[mid_good:] 72938
# len of poor summ[mid_poor:] 11983
# len of X 84921
# len of X_test 84921
# [['great except it doesnt clean well'], ['months later still a favorite case'], ['perfect case'], ['second one more will follow'], ['great product at a great price'], ['so cute'], ['love it'], ['best case ever'], ['beautiful iphone case'], ['adorable'], ['mybat iphone 4s case'], ['love it'], ['love it'], ['love it'], ['product review'], ['great product'], ['well made'], ['kids love it'], ['purple bubble case'], ['very cute'], ['oh my i love it'], ['loved it'], ['soooo cute'], ['loved it'], ['great case'], ['you get what you pay for'], ['great case for the money'], ['perfect cover for my husbands phone'], ['love the case'], ['best case ever'], ['perfect gift'], ['loved it'], ['bubbles'], ['what a cool case'], ['it looks cool and nice'], ['love it'], ['i like the color'], ['a year'], ['fits great'], ['awesome x2'], ['fits great'], ['a very good protector'], ['awesome'], ['sturdy and good protection i love that'], ['nice case'], ['i love it'], ['s3 screen protector'], ['acceptable'], ['like this product'], ['clear'], ['super screen protector'], ['best screen cover'], ['best value for money'], ['definite color noise effect'], ['wow'], ['great fit'], ['great matte finish screen protector'], ['protects & improves'], ['screen protector works'], ['cant go wrong with this screen protector'], ['best screen protector'], ['it works for now'], ['galaxy s3'], ['works well'], ['looks good'], ['superb'], ['love it'], ['no more smears'], ['great screen protector and help video'], ['perfect'], ['perfect'], ['will update but in the meantime'], ['great buy'], ['urban armor gear'], ['finally a good case'], ['iphone like case block + durability'], ['awesome case'], ['love this case'], ['best case ever'], ['good case great protection'], ['best case for the galaxy s3'], ['cool case'], ['great case'], ['the best case out there for the sgs3 beware of fakes'], ['awesome'], ['love it got all the colors'], ['love it'], ['love it'], ['fits better than any other case'], ['quality product'], ['great'], ['this case is great'], ['excellent case'], ['good solid case'], ['excellent'], ['looks cool good protection no clip'], ['fits snug but doesnt seem to provide much protection'], ['great slim fit'], ['great case but not sure why they bother including a screen protector'], ['best case so far'], ['rugged and functional without major bulk'], ['rugged rugged and good-looking phone case'], ['unbreakable probably'], ['exactly as i expected'], ['samsung phone case'], ['perhaps the best case ive had'], ['great case'], ['really cool'], ['urban armor gear case for samsung galaxy s iii rust'], ['nice looking case'], ['best case for the gs3'], ['gift for hubby'], ['looks great functions pretty well'], ['great case'], ['the best choce'], ['great rugged case'], ['finally a perfect case'], ['perfect case for the samsung galaxy s3'], ['its all one piece'], ['cool'], ['wrong case'], ['great case'], ['get alot of complements'], ['loved this case'], ['great protection'], ['works well'], ['i like it but not convinved'], ['excellent'], ['this case is awesome'], ['fantastic '], ['cover for my samsung galaxy s3'], ['very sturdy form fitting case highly recommended'], ['great for the price'], ['the best phone case ive ever had'], ['rugged'], ['best case for the s3 hands down'], ['sweet case'], ['best case ever'], ['rugged to the core'], ['absolutely perfect fit'], ['best phone case'], ['the best'], ['best case ever'], ['awesome case'], ['looks great'], ['its a cool case'], ['best looking case out there'], ['good not perfect'], ['awesome'], ['very beautiful case for my phone'], ['he likes it'], ['sturdy and looks great  better than otterbox'], ['nice alternative to a bulky case'], ['excellent case'], ['bad ass case'], ['happy'], ['my mother loves it'], ['im in love with this case'], ['uag case'], ['replaced'], ['cool looking'], ['great product'], ['awesome'], ['best case for galaxy phones s3 s4 etc - hands down'], ['elegant and rugged at the same time'], ['samsung galaxy 3'], ['favorit ...

# %%
# count vectorizer
cv = CountVectorizer(binary=True, lowercase=False)
cv.fit(summaries_train_clean)
# X = cv.transform(summaries_train_clean)
# X_test = cv.transform(summaries_test_clean)

# X
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-f6d3eb7c64b6> in <module>()
#       1 # count vectorizer
#       2 cv = CountVectorizer(binary=True, lowercase=False)
# ----> 3 cv.fit(summaries_train_clean)
#       4 # X = cv.transform(summaries_train_clean)
#       5 # X_test = cv.transform(summaries_test_clean)
#
# /Users/AngYang/anaconda/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in fit(self, raw_documents, y)
#     804         self
#     805         """
# --> 806         self.fit_transform(raw_documents)
#     807         return self
#     808
#
# /Users/AngYang/anaconda/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in fit_transform(self, raw_documents, y)
#     837
#     838         vocabulary, X = self._count_vocab(raw_documents,
# --> 839                                           self.fixed_vocabulary_)
#     840
#     841         if self.binary:
#
# /Users/AngYang/anaconda/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in _count_vocab(self, raw_documents, fixed_vocab)
#     760         for doc in raw_documents:
#     761             feature_counter = {}
# --> 762             for feature in analyze(doc):
#     763                 try:
#     764                     feature_idx = vocabulary[feature]
#
# /Users/AngYang/anaconda/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in <lambda>(doc)
#     239
#     240             return lambda doc: self._word_ngrams(
# --> 241                 tokenize(preprocess(self.decode(doc))), stop_words)
#     242
#     243         else:
#
# /Users/AngYang/anaconda/lib/python3.5/site-packages/sklearn/feature_extraction/text.py in <lambda>(doc)
#     214             return self.tokenizer
#     215         token_pattern = re.compile(self.token_pattern)
# --> 216         return lambda doc: token_pattern.findall(doc)
#     217
#     218     def get_stop_words(self):
#
# TypeError: expected string or bytes-like object
